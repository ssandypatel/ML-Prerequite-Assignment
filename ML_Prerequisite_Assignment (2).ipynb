# %% [markdown]
# # Machine Learning Prerequite Assignment

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import time

# %% [markdown]
# # Question 09
# Using matplotlib plot the following functions on the domain: x = 0.5 to 100.0 in steps of 0.5.

# %% [markdown]
# ![functions.png](attachment:functions.png)

# %%
x = np.linspace(0.5, 100.0, 200)

# %%
# 01.
y = x
plt.plot(x,y, '-r')

# %%
# 02.
y = x**2
plt.plot(x,y, '-r')

# %%
# 03.
y = (x**3)/100
plt.plot(x,y, '-r')

# %%
# 04.
y = np.sin(x)
plt.plot(x,y, '-r')

# %%
# 05.
y = np.sin(x)/x
plt.plot(x, y, '-g')

# %%
# 06.
y = np.log(x)
plt.plot(x,y, '-r')

# %%
# 07.
y = np.exp(x)
plt.plot(x,y, '-r')

# %% [markdown]
# # Question 07
# Create a Python nested dictionary to represent hierarchical information. We want to store record of students and their marks. Something like:
#
# ![dict.png](attachment:dict.png)

# %%
dic = {2022:{'Branch 1':{'Roll Number':1,'Name':'N','Marks':{'Maths':100,'English':70}
                        },
          'Branch 2':{}},
       2023:{'Branch 1':{},'Branch 2':{}},
       2024:{'Branch 1':{},'Branch 2':{}},
       2025:{'Branch 1':{},'Branch 2':{}}
      }
dic
# Out:
# {2022: {'Branch 1': {'Roll Number': 1,
#    'Name': 'N',
#    'Marks': {'Maths': 100, 'English': 70}},
#   'Branch 2': {}},
#  2023: {'Branch 1': {}, 'Branch 2': {}},
#  2024: {'Branch 1': {}, 'Branch 2': {}},
#  2025: {'Branch 1': {}, 'Branch 2': {}}}

# %% [markdown]
# # Question 8

# %%
class student:
  def __init__(self, rollno, name, year, marks,branch):
    self.name = name
    self.marks = marks
    self.rollno = rollno
    self.year = year
    self.branch = branch
    

  def toshow(self):
    print('Name:',self.name)
    yearlist = [2022,2023,2024,2025]
    marks = {'Maths':100, 'English':70}
    if self.year in yearlist:
        print('Year:',self.year)
    else:
        print('Year: No record found')
    print('Roll no:',self.year)
    print('Branch:',self.branch)
    if self.rollno==1:
        print('Marks:',self.marks)
    else:
        print('Marks: No record found')

                              
obj = student(1,'N',2027,75,'Branch 1')
print(obj.toshow())
# Out:
# Name: N
# Year: No record found
# Roll no: 2027
# Branch: Branch 1
# Marks: 75
# None

# %% [markdown]
# # Question 04
# What is the gradient of the following function with respect to x and y?
# $$ {f(x,y) = x^2y+y^3\sin(x)} $$

# %% [markdown]
# Gradient of the given function is given by
#
# $$ {(2xy+y^3\cos(x))\vec{a_x}}+{(x^2+3y^2\sin (x))\vec{a_y}} $$

# %% [markdown]
# # Question 05
# Use JAX to confirm the gradient evaluated by your method matches the analytical solution corresponding to a few random values of x and y

# %%
#This program throws error saying no module named jax is found
import jax.numpy as jnp
from jax import *

def f(x,y):
    return (x**2)*y + (y**3)*jnp.sin(x)


x = jnp.array([0,1,2])
y = jnp.array([0,1,1])
gradient = jax.grad(f)
print(gradient(x,y))

# %% [markdown]
# # Question 06
# Use sympy to confirm that you obtain the same gradient analytically.

# %%
import sympy as sy
from sympy import *
x,y,i,j = sy.symbols('x y i j')

f = (x**2)*y + (y**3)*sin(x)

f_dash_x = sy.diff(f, x)#wrt x
f_dash_y = sy.diff(f, y)#wrt y

gradient = f_dash_x*i +f_dash_y*j #gradient representation
print(gradient)

#Reference:
#https://medium.com/@ilmunabid/how-to-find-a-gradient-slope-of-a-function-in-python-774f865467d2

# %% [markdown]
# # Question 10
# Using numpy generate a matrix of size 20X5 containing random numbers drawn uniformly from the range of 1 to 2. Using Pandas create a dataframe out of this matrix. Name the columns of the dataframe as “a”, “b”, “c”, “d”, “e”. Find the column with the highest standard deviation. Find the row with the lowest mean.

# %%
rand = np.random.rand(20,5)
matrix = rand+1
# matrix

dataframe = pd.DataFrame(matrix, columns = ['a','b','c','d','e'], index = [i for i in range(1,21)])
dataframe
# Out:
#            a         b         c         d         e
# 1   1.570083  1.866959  1.327900  1.831346  1.108565
# 2   1.374221  1.864153  1.500115  1.686887  1.240921
# 3   1.592425  1.784881  1.836064  1.134679  1.750776
# 4   1.480511  1.504625  1.502155  1.828399  1.413678
# 5   1.480751  1.041550  1.442577  1.681224  1.356067
# 6   1.807337  1.662499  1.572233  1.094394  1.313461
# 7   1.129432  1.963459  1.104586  1.039671  1.515061
# 8   1.479711  1.484993  1.524500  1.364909  1.058046
# 9   1.800431  1.104814  1.761617  1.385940  1.884027
# 10  1.144790  1.649622  1.231366  1.312456  1.814792
# 11  1.861580  1.932410  1.443873  1.495352  1.654773
# 12  1.647139  1.498494  1.455750  1.818494  1.735715
# 13  1.663096  1.227931  1.409114  1.890874  1.577598
# 14  1.181931  1.968109  1.369034  1.386215  1.383116
# 15  1.254994  1.111352  1.877130  1.043965  1.387628
# 16  1.492910  1.424784  1.223100  1.845258  1.172439
# 17  1.226610  1.696879  1.592613  1.148062  1.414687
# ...

# %%
stdev_col = dataframe.std()
def find_max_stdev_col(x): #finding col with max stdeviation
    max_val = -10
    col = None
    for key, val in x.items():
        if val>max_val:
            max_val = val
            col = key
    return col

# %%
print("Column with maximum standard deviation is",find_max_stdev_col(stdev_col))
# Out:
# Column with maximum standard deviation is b

# %%
mean_val_row = dataframe.mean(axis =1)
mean_val_row
# Out:
# 1     1.540971
# 2     1.533259
# 3     1.619765
# 4     1.545874
# 5     1.400434
# 6     1.489985
# 7     1.350442
# 8     1.382432
# 9     1.587366
# 10    1.430605
# 11    1.677598
# 12    1.631118
# 13    1.553723
# 14    1.457681
# 15    1.335014
# 16    1.431698
# 17    1.415770
# 18    1.317017
# 19    1.486471
# 20    1.680061
# dtype: float64

# %%
def find_min_mean_row(x):
    max_val = 10
    row =-1
    for key, val in x.items():
        if val<max_val:
            max_val = val
            row = key
    return row

print('The row with minimum mean value is:',find_min_mean_row(mean_val_row))
# Out:
# The row with minimum mean value is: 18

# %% [markdown]
# # Question 11
# Add a new column to the dataframe called “f” which is the sum of the columns “a”, “b”, “c”, “d”, “e”. Create another column called “g”. The value in the column “g” should be “LT8” if the value in the column “f” is less than 8 and “GT8” otherwise. Find the number of rows in the dataframe where the value in the column “g” is “LT8”. Find the standard deviation of the column “f” for the rows where the value in the column “g” is “LT8” and “GT8” respectively.

# %%
#Using above dataframe
#To add f col as sum of all other columns
dataframe['f'] = dataframe['a']+dataframe['b']+dataframe['c']+dataframe['d']+dataframe['e']
dataframe
# Out:
#            a         b         c         d         e         f
# 1   1.570083  1.866959  1.327900  1.831346  1.108565  7.704853
# 2   1.374221  1.864153  1.500115  1.686887  1.240921  7.666297
# 3   1.592425  1.784881  1.836064  1.134679  1.750776  8.098826
# 4   1.480511  1.504625  1.502155  1.828399  1.413678  7.729368
# 5   1.480751  1.041550  1.442577  1.681224  1.356067  7.002170
# 6   1.807337  1.662499  1.572233  1.094394  1.313461  7.449923
# 7   1.129432  1.963459  1.104586  1.039671  1.515061  6.752210
# 8   1.479711  1.484993  1.524500  1.364909  1.058046  6.912159
# 9   1.800431  1.104814  1.761617  1.385940  1.884027  7.936829
# 10  1.144790  1.649622  1.231366  1.312456  1.814792  7.153027
# 11  1.861580  1.932410  1.443873  1.495352  1.654773  8.387988
# 12  1.647139  1.498494  1.455750  1.818494  1.735715  8.155591
# 13  1.663096  1.227931  1.409114  1.890874  1.577598  7.768614
# 14  1.181931  1.968109  1.369034  1.386215  1.383116  7.288404
# ...

# %%
#To add g col according to given condition
g_col = np.array(['LT8'  if dataframe['f'][i]<8 else 'GT8' for i in range(1,21) ])
# g_col
dataframe['g'] = g_col
dataframe
# Out:
#            a         b         c         d         e         f    g
# 1   1.570083  1.866959  1.327900  1.831346  1.108565  7.704853  LT8
# 2   1.374221  1.864153  1.500115  1.686887  1.240921  7.666297  LT8
# 3   1.592425  1.784881  1.836064  1.134679  1.750776  8.098826  GT8
# 4   1.480511  1.504625  1.502155  1.828399  1.413678  7.729368  LT8
# 5   1.480751  1.041550  1.442577  1.681224  1.356067  7.002170  LT8
# 6   1.807337  1.662499  1.572233  1.094394  1.313461  7.449923  LT8
# 7   1.129432  1.963459  1.104586  1.039671  1.515061  6.752210  LT8
# 8   1.479711  1.484993  1.524500  1.364909  1.058046  6.912159  LT8
# 9   1.800431  1.104814  1.761617  1.385940  1.884027  7.936829  LT8
# 10  1.144790  1.649622  1.231366  1.312456  1.814792  7.153027  LT8
# 11  1.861580  1.932410  1.443873  1.495352  1.654773  8.387988  GT8
# 12  1.647139  1.498494  1.455750  1.818494  1.735715  8.155591  GT8
# 13  1.663096  1.227931  1.409114  1.890874  1.577598  7.768614  LT8
# ...

# %%
#To find the no of rows where value in g col is 'LT8'
count = 0
for i in dataframe['g']:
    if i =='LT8':
        count+=1
count
# Out:
# 16

# %%
#To find standard deviation of f col for which row value in g col is 'LT8' and 'GT8' respectively

lst_lt8 = []
lst_gt8= []
for key, val in dataframe['g'].items():
    if val =='LT8':
        lst_lt8.append(key)
    elif(val =='GT8'):
        lst_gt8.append(key)
# lst_lt8
# lst_gt8
std_f_lt8 = dataframe['f'][lst_lt8].std()
std_f_gt8 = dataframe['f'][lst_gt8].std()
print('For LT8, Std is:',std_f_lt8)
print("For GT8, Std is:", std_f_gt8)
# Out:
# For LT8, Std is: 0.42135255603217964
# For GT8, Std is: 0.15593091827151057

# %% [markdown]
# # Question 13
# Write a function to compute the argmin of a numpy array. The function should take a numpy array as input and return the index of the minimum element. You can use the np.argmin function to verify your solution.

# %%
#Function to fing the index of minimum element of a numpy array
def argmin(arr):
    min_val = 10000000
    index = -1
    for i in range(len(arr)):
        if arr[i]<min_val:
            min_val = arr[i]
            index = i
    return index


arr = np.array([1,2,43,56,576,68,8,6,53,4,3212,4,455,6,78,-435,5,-67,5])
# arr = np.random.rand(1000)

print("My function result:", argmin(arr),"; Builtin function result:",np.argmin(arr))
# Out:
# My function result: 15 ; Builtin function result: 15

# %% [markdown]
# # Question 03
# Finding the highest element in a list requires one pass of the array. Finding the second highest element requires 2 passes of the the array. Using this method, what is the time complexity of finding the median of the array? Can you suggest a better method? Can you implement both these methods in Python and compare against numpy.median routine in terms of time?

# %%
#Finding highest element in one pass

def find_highest_element(arr):
    max_val = -1000000
    for i in arr:
        if i>max_val:
            max_val = i
    return max_val


arr = np.array([np.random.rand() for i in range(100)])
# arr = np.array([1,2,43,56,576,68,8,6,5334,4,3212,4,455,6,78,-435,5,-67,5])
find_highest_element(arr)

# %%
# Finding the second highest element using 2 pass
def find_second_highest(arr):
    max_val = -1000000    
    for i in arr:
        if i>max_val:
            max_val = i
            
    arr = np.delete(arr, np.argwhere(arr==max_val))#Deletion by value
    
    
    
    max_val = -1000000  
    for i in arr:
        if i>max_val:
            max_val = i
    
     
    
    return max_val


arr = np.array([1,2,43,56,576,68,8,6,53,4,3212,4,455,6,78,-435,5,-67,5])
find_second_highest(arr)
# Out:
# 576

# %% [markdown]
# Time complexity of finding median of array using above approach will be
#  $$ O(n^2)$$
#
#  We can first sort the array and then use the mathematical formula for finding median

# %%
start = time.time()

def find_median(arr):    
    n = len(arr)
    if n%2==1:
        for j in range((n//2)+1):
            max_val = -1000000
            for i in arr:
                if i>max_val:
                    max_val = i
            
            arr = np.delete(arr, np.argwhere(arr==max_val))#Deletion by value
    else:
        for j in range((n//2)+1):
            max_val = -1000000
            for i in arr:
                if i>max_val:
                    max_val = i
            if j==(n/2)-1:
                max_val1 = max_val
            arr = np.delete(arr, np.argwhere(arr==max_val))#Deletion by value
    
    return (max_val1 + max_val)/2



# arr = np.array([2,43,56,576,68,8,6,5334,4,3212,4,455,6,78,-435,5,-67,5])
# arr = np.arange(1,7)
arr = np.random.random(10000)
userdefined_median = find_median(arr)

end = time.time()

print('My function result',userdefined_median, end = " ")
print('Time taken:', end-start,'seconds')


#Using Builtin np.median function
start = time.time()
builtin_median = np.median(arr)
end = time.time()

print('Builtin Function result',builtin_median, end = ' ')
print('Time taken:', end-start,'seconds')
# Out:
# My function result 0.5027968560315446 Time taken: 5.986150503158569 seconds
# Builtin Function result 0.5027968560315446 Time taken: 0.0 seconds

# %% [markdown]
# Here, we can clearly see builtin median function taken almost zero time whereas user defined function takes few seconds for large array.

# %% [markdown]
# # Question 01
# How many multiplications and additions do you need to perform a matrix multiplication between a (n, k) and (k, m) matrix? Explain.

# %% [markdown]
# Here we have nxk and kxm matrices to multiply. Considering row by column multiplication,
# for first element of resultant matrix, using first row of first matrix(k elemnts) and first column of 2nd matrix (k elements) k multiplications and k-1 additions will be performed.
#
# But there will be n*m elements in the resultant matrix(nxm matrix), so
#
# Total no. of multiplications  = n*m*k
#
# Total no. of additions =  n*m*(k-1)

# %% [markdown]
# # Question 02
# Write Python code to multiply the above two matrices. Solve using list of lists and then use numpy. Compare the timing of both solutions. Which one is faster? Why?

# %%
# Using Nested lists
start = time.time()

def matrix_multiplication(m1,m2):   
    
    n = len(m1)
    m= len(m2[0])
    k1 = len(m1[0])
    result = [[0 for i in range(m)] for i in range(n)] #Initialising matrix using list comprehension   
    
    for i in range(n):
        for j in range(m):
            for k in range(k1):
                result[i][j] += (m1[i][k] * m2[k][j])
    return result


# m1 = [[2,3,5],[4,3,2]]
# m2 = [[2,3],[4,5],[6,7]]
m1 = np.random.randint(100, size=(20, 80))
m2 = np.random.randint(1000, size=(80, 20))
print(matrix_multiplication(m1,m2))
end = time.time()
print('Time taken:',end - start)
# Out:
# Wall time: 0 ns
# ...

# %%
# Using Numpy array
start = time.time()
def matrix_multiplication(m1,m2):   
    
    n = len(m1)
    m= len(m2[0])
    result = np.zeros((n,m), dtype = int) #Initialisation  
    m2 = m2.T
    for i in range(n):
        for j in range(m):
            result[i][j] = np.sum(m1[i]*m2[j])
    return result


# m1 = np.array([[2,3,5],[4,3,2]])
# m2 = np.array([[2,3],[4,5],[6,7]])

m1 = np.random.randint(100, size=(20, 80))
m2 = np.random.randint(1000, size=(80, 20))

print(matrix_multiplication(m1,m2))
end = time.time()
print('Time taken:',end - start)
# Out:
# [[1813519 1854575 1716072 1835733 1851358 1743778 1752632 1733997 1653050
#   1948774 1542467 1545516 1681337 1777611 1795692 1498734 1749492 1530170
#   1614075 1748040]
#  [2033295 2250174 2110384 2208075 1913207 1877080 2109146 2118506 1908414
#   2217919 1653263 1768853 1915722 2183645 2152571 1773342 1946006 1852943
#   1823203 1861818]
#  [1812435 2142283 1994968 2031078 1701647 1932247 1957603 1822068 1741324
#   1955755 1596715 1719575 1778809 1992303 2024466 1721844 1969573 1822872
#   1813102 1695266]
#  [2053741 2180451 2294749 2143039 1958983 2003788 2126505 2184016 2054967
#   2205325 1722347 1757199 1906860 2106104 2162652 1847094 2007712 1873795
#   2021845 2062919]
#  [1837460 1815515 1774013 1876017 1727552 1664682 1666349 1939906 1718275
#   1928578 1541075 1708062 1559772 1971377 1851341 1565600 1713712 1689807
#   1735888 1795540]
#  [2016551 2368114 2149817 2272384 1924990 2054785 2004221 1979984 1900769
# ...

# %% [markdown]
# ###### Here  we can clearly see time taken in multiplication using numpy array is lower than that of using nested lists. This difference is occuring for smaller matrices. For very large matrices this gap will be very significant.
#
# Hence, numpy approch is much faster than nested list.

# %% [markdown]
# # Question 12
# Write a small piece of code to explain broadcasting in numpy.

# %% [markdown]
# #####
# If both array have different no.of dimesions, array with lesser dimensions will be padded 1 as dimension to its left.
#
# if the dimensions of both the array are still different, then they can be broadcast only when the smaller of each dimension of two array is 1. In any other condition, it will throw a error.

# %%
#Here, the commented print statements can not be broadcasted. on executing they will throw errors.
m1 = np.ones((2,3), dtype = int)#(2,3)
m2 = np.random.randint(20, size = (3,3))#(3,3)
m3 = np.array([1,2,3])#(1,3)
m4 = np.array([1,2,3,4])#(1,4)
m5 = np.arange(3)#it will be padded with 1, so becomes (1,3)

# print(m1+m2)
print(m1+m3)
# print(m1+m4)
print(m1+m5)
print(m3+m2)
# print(m4+m2)
print(m5+m2)
# Out:
# [[2 3 4]
#  [2 3 4]]
# [[1 2 3]
#  [1 2 3]]
# [[ 6 18  5]
#  [19 11 16]
#  [ 5  9 10]]
# [[ 5 17  4]
#  [18 10 15]
#  [ 4  8  9]]
